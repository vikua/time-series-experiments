# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import matplotlib.pyplot as plt

from time_series_experiments import utils
from time_series_experiments import baseline
from time_series_experiments import transformer

tf.get_logger().setLevel('ERROR')

# %%
seed = 0xC0FFEE
fdw = 36
fw = 12

sunspot_df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv')

# %%
plt.plot(np.arange(sunspot_df.shape[0]), sunspot_df['Sunspots'].values)

# %%
y = sunspot_df['Sunspots'].values

x_train_idx, y_train_idx, x_test_idx, y_test_idx = utils.train_test_split_index(
    y.shape[0], fdw, fw, test_size=0.1, random_seed=seed, shuffle_train=False
)

x_train = np.expand_dims(y[x_train_idx], axis=-1)
y_train = y[y_train_idx]
x_test = np.expand_dims(y[x_test_idx], axis=-1)
y_test = y[y_test_idx]

# %%
x_train.shape
# Out:
# (2496, 36, 1)

# %%
xplot = np.arange(fdw + fw)
plt.plot(xplot[:fdw], x_train[100])
plt.plot(xplot[-fw:], y_train[100])

# %%
baseline_model = baseline.LatestNaiveBaseline(fw=fw)
y_pred_baseline = baseline_model.predict(x_test)
print('RMSE', utils.rmse(y_test, y_pred_baseline))
# Out:
# RMSE 28.108357571067014

# %%
scaler = utils.ScalerWrapper(StandardScaler(), log_transform=False)
scaler.fit(x_train)

xtr = scaler.transform(x_train)
ytr = scaler.transform(y_train)

xt = scaler.transform(x_test)
yt = scaler.transform(y_test)

attention_dim = 32
num_heads = 4
epochs = 200
batch_size = 32

transformer_model = transformer.Transformer(
    num_layers=1,
    attention_dim=attention_dim,
    num_heads=num_heads,
    hidden_kernel_initializer=utils.get_initializer("glorot_uniform", seed),
    attention_kernel_initializer=utils.get_initializer("glorot_uniform", seed),
    pwffn_kernel_initializer=utils.get_initializer("glorot_uniform", seed),
    output_kernel_initializer=utils.get_initializer("glorot_uniform", seed),
    layer_norm_epsilon=None,
    epochs=epochs,
    batch_size=batch_size,
    optimizer=keras.optimizers.Adam(0.001),
    loss=keras.losses.MeanSquaredError(),
)
history = transformer_model.fit(
    xtr, 
    ytr, 
    verbose=1, 
    shuffle=True,
    validation_split=0.1,
)
# Out:
# Train on 2246 samples, validate on 250 samples
# Epoch 1/200
# 2246/2246 [==============================] - 4s 2ms/sample - loss: 8.7524 - val_loss: 0.4367
# Epoch 2/200
# 2246/2246 [==============================] - 2s 894us/sample - loss: 0.1616 - val_loss: 0.3398
# Epoch 3/200
# 2246/2246 [==============================] - 2s 961us/sample - loss: 0.1413 - val_loss: 0.2878
# Epoch 4/200
# 2246/2246 [==============================] - 2s 929us/sample - loss: 0.1293 - val_loss: 0.4110
# Epoch 5/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1260 - val_loss: 0.4149
# Epoch 6/200
# 2246/2246 [==============================] - 2s 917us/sample - loss: 0.1243 - val_loss: 0.3834
# Epoch 7/200
# 2246/2246 [==============================] - 2s 970us/sample - loss: 0.1231 - val_loss: 0.4197
# Epoch 8/200
# 2246/2246 [==============================] - 2s 927us/sample - loss: 0.1245 - val_loss: 0.2898
# Epoch 9/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1234 - val_loss: 0.3300
# Epoch 10/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1225 - val_loss: 0.3179
# Epoch 11/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1236 - val_loss: 0.2709
# Epoch 12/200
# 2246/2246 [==============================] - 2s 961us/sample - loss: 0.1214 - val_loss: 0.2566
# Epoch 13/200
# 2246/2246 [==============================] - 3s 1ms/sample - loss: 0.1219 - val_loss: 0.2926
# Epoch 14/200
# 2246/2246 [==============================] - 2s 998us/sample - loss: 0.1220 - val_loss: 0.3583
# Epoch 15/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1232 - val_loss: 0.4640
# Epoch 16/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1219 - val_loss: 0.4083
# Epoch 17/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1204 - val_loss: 0.6719
# Epoch 18/200
# 2246/2246 [==============================] - 3s 1ms/sample - loss: 0.1196 - val_loss: 0.4882
# Epoch 19/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1217 - val_loss: 0.5121
# Epoch 20/200
# 2246/2246 [==============================] - 2s 984us/sample - loss: 0.1209 - val_loss: 0.5556
# Epoch 21/200
# 2246/2246 [==============================] - 2s 890us/sample - loss: 0.1193 - val_loss: 0.5435
# Epoch 22/200
# 2246/2246 [==============================] - 2s 784us/sample - loss: 0.1194 - val_loss: 0.5261
# Epoch 23/200
# 2246/2246 [==============================] - 2s 812us/sample - loss: 0.1201 - val_loss: 0.7300
# Epoch 24/200
# 2246/2246 [==============================] - 2s 925us/sample - loss: 0.1211 - val_loss: 0.5464
# Epoch 25/200
# 2246/2246 [==============================] - 2s 896us/sample - loss: 0.1173 - val_loss: 0.7707
# Epoch 26/200
# 2246/2246 [==============================] - 2s 898us/sample - loss: 0.1178 - val_loss: 0.6750
# Epoch 27/200
# 2246/2246 [==============================] - 2s 913us/sample - loss: 0.1194 - val_loss: 0.5911
# Epoch 28/200
# 2246/2246 [==============================] - 2s 862us/sample - loss: 0.1192 - val_loss: 0.7124
# Epoch 29/200
# 2246/2246 [==============================] - 2s 859us/sample - loss: 0.1194 - val_loss: 0.4397
# Epoch 30/200
# 2246/2246 [==============================] - 2s 778us/sample - loss: 0.1182 - val_loss: 0.7204
# Epoch 31/200
# 2246/2246 [==============================] - 2s 917us/sample - loss: 0.1192 - val_loss: 0.7336
# Epoch 32/200
# 2246/2246 [==============================] - 2s 932us/sample - loss: 0.1182 - val_loss: 0.6072
# Epoch 33/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1192 - val_loss: 0.8323
# Epoch 34/200
# 2246/2246 [==============================] - 2s 889us/sample - loss: 0.1170 - val_loss: 0.9878
# Epoch 35/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1184 - val_loss: 0.9656
# Epoch 36/200
# 2246/2246 [==============================] - 2s 973us/sample - loss: 0.1171 - val_loss: 0.9990
# Epoch 37/200
# 2246/2246 [==============================] - 2s 954us/sample - loss: 0.1153 - val_loss: 0.8717
# Epoch 38/200
# 2246/2246 [==============================] - 2s 990us/sample - loss: 0.1187 - val_loss: 0.6216
# Epoch 39/200
# 2246/2246 [==============================] - 2s 940us/sample - loss: 0.1145 - val_loss: 1.0555
# Epoch 40/200
# 2246/2246 [==============================] - 2s 912us/sample - loss: 0.1163 - val_loss: 0.8048
# Epoch 41/200
# 2246/2246 [==============================] - 2s 983us/sample - loss: 0.1178 - val_loss: 0.7692
# Epoch 42/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1175 - val_loss: 0.6001
# Epoch 43/200
# 2246/2246 [==============================] - 2s 870us/sample - loss: 0.1174 - val_loss: 0.7163
# Epoch 44/200
# 2246/2246 [==============================] - 2s 926us/sample - loss: 0.1160 - val_loss: 0.6534
# Epoch 45/200
# 2246/2246 [==============================] - 2s 854us/sample - loss: 0.1141 - val_loss: 0.7208
# Epoch 46/200
# 2246/2246 [==============================] - 2s 861us/sample - loss: 0.1148 - val_loss: 0.7445
# Epoch 47/200
# 2246/2246 [==============================] - 2s 931us/sample - loss: 0.1134 - val_loss: 0.7001
# Epoch 48/200
# 2246/2246 [==============================] - 2s 930us/sample - loss: 0.1127 - val_loss: 0.5116
# Epoch 49/200
# 2246/2246 [==============================] - 2s 912us/sample - loss: 0.1163 - val_loss: 0.8726
# Epoch 50/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1137 - val_loss: 0.7752
# Epoch 51/200
# 2246/2246 [==============================] - 2s 859us/sample - loss: 0.1149 - val_loss: 0.8662
# Epoch 52/200
# 2246/2246 [==============================] - 2s 876us/sample - loss: 0.1164 - val_loss: 0.7917
# Epoch 53/200
# 2246/2246 [==============================] - 2s 947us/sample - loss: 0.1167 - val_loss: 0.7127
# Epoch 54/200
# 2246/2246 [==============================] - 2s 954us/sample - loss: 0.1152 - val_loss: 0.5954
# Epoch 55/200
# 2246/2246 [==============================] - 2s 1ms/sample - loss: 0.1148 - val_loss: 0.8089
# Epoch 56/200
# 2246/2246 [==============================] - 2s 985us/sample - loss: 0.1136 - val_loss: 0.8725
# Epoch 57/200
# 2246/2246 [==============================] - 2s 948us/sample - loss: 0.1119 - val_loss: 0.8976
# Epoch 58/200
# 2246/2246 [==============================] - 2s 922us/sample - loss: 0.1112 - val_loss: 0.9895
# Epoch 59/200
# 2246/2246 [==============================] - 2s 968us/sample - loss: 0.1113 - val_loss: 0.8466
# Epoch 60/200
# 2246/2246 [==============================] - 2s 986us/sample - loss: 0.1097 - val_loss: 0.6359
# Epoch 61/200
# 2246/2246 [==============================] - 2s 870us/sample - loss: 0.1109 - val_loss: 0.7539
# Epoch 62/200
# 2246/2246 [==============================] - 2s 938us/sample - loss: 0.1127 - val_loss: 0.9002
# Epoch 63/200
# 2246/2246 [==============================] - 2s 999us/sample - loss: 0.1102 - val_loss: 0.6962
# Epoch 64/200
# 2246/2246 [==============================] - 2s 876us/sample - loss: 0.1162 - val_loss: 0.8054
# Epoch 65/200
# 2246/2246 [==============================] - 2s 815us/sample - loss: 0.1089 - val_loss: 0.8522
# Epoch 66/200
# 2246/2246 [==============================] - 2s 783us/sample - loss: 0.1070 - val_loss: 0.5229
# Epoch 67/200
# 2246/2246 [==============================] - 2s 775us/sample - loss: 0.1153 - val_loss: 0.8792
# Epoch 68/200
# 2246/2246 [==============================] - 2s 918us/sample - loss: 0.1096 - val_loss: 0.6062
# Epoch 69/200
# 2246/2246 [==============================] - 2s 795us/sample - loss: 0.1077 - val_loss: 1.2243
# Epoch 70/200
# 2246/2246 [==============================] - 2s 703us/sample - loss: 0.1068 - val_loss: 1.7845
# Epoch 71/200
# 2246/2246 [==============================] - 2s 678us/sample - loss: 0.1136 - val_loss: 0.6018
# Epoch 72/200
# 2246/2246 [==============================] - 1s 651us/sample - loss: 0.1065 - val_loss: 0.7488
# Epoch 73/200
# 2246/2246 [==============================] - 1s 630us/sample - loss: 0.1136 - val_loss: 0.7648
# Epoch 74/200
# 2246/2246 [==============================] - 1s 606us/sample - loss: 0.1084 - val_loss: 0.9729
# Epoch 75/200
# 2246/2246 [==============================] - 1s 617us/sample - loss: 0.1067 - val_loss: 1.0983
# Epoch 76/200
# 2246/2246 [==============================] - 1s 589us/sample - loss: 0.1050 - val_loss: 1.1704
# Epoch 77/200
# 2246/2246 [==============================] - 1s 614us/sample - loss: 0.1072 - val_loss: 0.8799
# Epoch 78/200
# 2246/2246 [==============================] - 2s 710us/sample - loss: 0.1037 - val_loss: 0.6367
# Epoch 79/200
# 2246/2246 [==============================] - 1s 615us/sample - loss: 0.1100 - val_loss: 0.7986
# Epoch 80/200
# 2246/2246 [==============================] - 1s 607us/sample - loss: 0.1062 - val_loss: 0.8602
# Epoch 81/200
# 2246/2246 [==============================] - 1s 611us/sample - loss: 0.1029 - val_loss: 0.9097
# Epoch 82/200
# 2246/2246 [==============================] - 1s 608us/sample - loss: 0.1099 - val_loss: 0.7750
# Epoch 83/200
# 2246/2246 [==============================] - 1s 589us/sample - loss: 0.1051 - val_loss: 0.8851
# Epoch 84/200
# 2246/2246 [==============================] - 1s 634us/sample - loss: 0.1022 - val_loss: 0.9168
# Epoch 85/200
# 2246/2246 [==============================] - 2s 752us/sample - loss: 0.0997 - val_loss: 0.8708
# Epoch 86/200
# 2246/2246 [==============================] - 2s 809us/sample - loss: 0.1083 - val_loss: 0.9045
# Epoch 87/200
# 2246/2246 [==============================] - 1s 659us/sample - loss: 0.1063 - val_loss: 0.6398
# Epoch 88/200
# 2246/2246 [==============================] - 1s 639us/sample - loss: 0.1003 - val_loss: 0.8539
# Epoch 89/200
# 2246/2246 [==============================] - 1s 644us/sample - loss: 0.1006 - val_loss: 1.2429
# Epoch 90/200
# 2246/2246 [==============================] - 1s 657us/sample - loss: 0.1066 - val_loss: 0.6465
# Epoch 91/200
# 2246/2246 [==============================] - 1s 656us/sample - loss: 0.1006 - val_loss: 0.7517
# Epoch 92/200
# 2246/2246 [==============================] - 1s 652us/sample - loss: 0.0970 - val_loss: 1.0055
# Epoch 93/200
# 2246/2246 [==============================] - 2s 717us/sample - loss: 0.0967 - val_loss: 0.4706
# Epoch 94/200
# 2246/2246 [==============================] - 1s 664us/sample - loss: 0.1151 - val_loss: 0.6633
# Epoch 95/200
# 2246/2246 [==============================] - 1s 647us/sample - loss: 0.1008 - val_loss: 0.7498
# Epoch 96/200
# 2246/2246 [==============================] - 1s 655us/sample - loss: 0.0950 - val_loss: 0.7757
# Epoch 97/200
# 2246/2246 [==============================] - 1s 667us/sample - loss: 0.0951 - val_loss: 0.7261
# Epoch 98/200
# 2246/2246 [==============================] - 2s 676us/sample - loss: 0.0973 - val_loss: 1.0006
# Epoch 99/200
# 2246/2246 [==============================] - 1s 665us/sample - loss: 0.1004 - val_loss: 0.4131
# Epoch 100/200
# 2246/2246 [==============================] - 2s 668us/sample - loss: 0.1013 - val_loss: 0.8531
# Epoch 101/200
# 2246/2246 [==============================] - 2s 779us/sample - loss: 0.0964 - val_loss: 0.6342
# Epoch 102/200
# 2246/2246 [==============================] - 2s 801us/sample - loss: 0.0952 - val_loss: 0.8049
# Epoch 103/200
# 2246/2246 [==============================] - 2s 705us/sample - loss: 0.0943 - val_loss: 0.7266
# Epoch 104/200
# 2246/2246 [==============================] - 1s 668us/sample - loss: 0.0968 - val_loss: 0.7369
# Epoch 105/200
# 2246/2246 [==============================] - 1s 663us/sample - loss: 0.0929 - val_loss: 0.8312
# Epoch 106/200
# 2246/2246 [==============================] - 2s 682us/sample - loss: 0.0888 - val_loss: 0.9520
# Epoch 107/200
# 2246/2246 [==============================] - 2s 676us/sample - loss: 0.0913 - val_loss: 0.9164
# Epoch 108/200
# 2246/2246 [==============================] - 2s 707us/sample - loss: 0.0896 - val_loss: 0.9201
# Epoch 109/200
# 2246/2246 [==============================] - 2s 747us/sample - loss: 0.0863 - val_loss: 0.8002
# Epoch 110/200
# 2246/2246 [==============================] - 2s 825us/sample - loss: 0.0845 - val_loss: 0.7038
# Epoch 111/200
# 2246/2246 [==============================] - 2s 807us/sample - loss: 0.0850 - val_loss: 0.8586
# Epoch 112/200
# 2246/2246 [==============================] - 2s 962us/sample - loss: 0.0886 - val_loss: 0.8781
# Epoch 113/200
# 2246/2246 [==============================] - 1s 658us/sample - loss: 0.0852 - val_loss: 0.5902
# Epoch 114/200
# 2246/2246 [==============================] - 1s 665us/sample - loss: 0.0889 - val_loss: 0.8848
# Epoch 115/200
# 2246/2246 [==============================] - 1s 638us/sample - loss: 0.0817 - val_loss: 0.8273
# Epoch 116/200
# 2246/2246 [==============================] - 1s 630us/sample - loss: 0.0874 - val_loss: 0.9264
# Epoch 117/200
# 2246/2246 [==============================] - 1s 650us/sample - loss: 0.0896 - val_loss: 0.8570
# Epoch 118/200
# 2246/2246 [==============================] - 1s 652us/sample - loss: 0.0813 - val_loss: 0.6167
# Epoch 119/200
# 2246/2246 [==============================] - 2s 679us/sample - loss: 0.0760 - val_loss: 0.8941
# Epoch 120/200
# 2246/2246 [==============================] - 2s 738us/sample - loss: 0.0857 - val_loss: 0.5833
# Epoch 121/200
# 2246/2246 [==============================] - 2s 715us/sample - loss: 0.0887 - val_loss: 0.7254
# Epoch 122/200
# 2246/2246 [==============================] - 2s 752us/sample - loss: 0.0808 - val_loss: 0.6872
# Epoch 123/200
# 2246/2246 [==============================] - 2s 771us/sample - loss: 0.0808 - val_loss: 0.6280
# Epoch 124/200
# 2246/2246 [==============================] - 1s 664us/sample - loss: 0.0881 - val_loss: 0.6130
# Epoch 125/200
# 2246/2246 [==============================] - 2s 725us/sample - loss: 0.0758 - val_loss: 0.7647
# Epoch 126/200
# 2246/2246 [==============================] - 1s 666us/sample - loss: 0.0721 - val_loss: 0.5883
# Epoch 127/200
# 2246/2246 [==============================] - 2s 683us/sample - loss: 0.0767 - val_loss: 1.1980
# Epoch 128/200
# 2246/2246 [==============================] - 2s 761us/sample - loss: 0.0716 - val_loss: 1.2425
# Epoch 129/200
# 2246/2246 [==============================] - 2s 750us/sample - loss: 0.0800 - val_loss: 0.9030
# Epoch 130/200
# 2246/2246 [==============================] - 2s 800us/sample - loss: 0.0765 - val_loss: 0.9041
# Epoch 131/200
# 2246/2246 [==============================] - 2s 729us/sample - loss: 0.0714 - val_loss: 0.7025
# Epoch 132/200
# 2246/2246 [==============================] - 2s 747us/sample - loss: 0.0763 - val_loss: 0.7273
# Epoch 133/200
# 2246/2246 [==============================] - 2s 670us/sample - loss: 0.0669 - val_loss: 1.0003
# Epoch 134/200
# 2246/2246 [==============================] - 1s 657us/sample - loss: 0.0739 - val_loss: 0.4927
# Epoch 135/200
# 2246/2246 [==============================] - 2s 670us/sample - loss: 0.0752 - val_loss: 0.6269
# Epoch 136/200
# 2246/2246 [==============================] - 1s 663us/sample - loss: 0.0762 - val_loss: 0.9320
# Epoch 137/200
# 2246/2246 [==============================] - 2s 722us/sample - loss: 0.0787 - val_loss: 0.7376
# Epoch 138/200
# 2246/2246 [==============================] - 1s 668us/sample - loss: 0.0653 - val_loss: 0.7005
# Epoch 139/200
# 2246/2246 [==============================] - 2s 719us/sample - loss: 0.0621 - val_loss: 0.7163
# Epoch 140/200
# 2246/2246 [==============================] - 2s 734us/sample - loss: 0.0634 - val_loss: 0.8503
# Epoch 141/200
# 2246/2246 [==============================] - 2s 686us/sample - loss: 0.0722 - val_loss: 0.6367
# Epoch 142/200
# 2246/2246 [==============================] - 2s 740us/sample - loss: 0.0683 - val_loss: 0.6792
# Epoch 143/200
# 2246/2246 [==============================] - 2s 723us/sample - loss: 0.0727 - val_loss: 0.6354
# Epoch 144/200
# 2246/2246 [==============================] - 1s 648us/sample - loss: 0.0649 - val_loss: 0.7216
# Epoch 145/200
# 2246/2246 [==============================] - 1s 658us/sample - loss: 0.0601 - val_loss: 0.8335
# Epoch 146/200
# 2246/2246 [==============================] - 1s 656us/sample - loss: 0.0609 - val_loss: 0.7431
# Epoch 147/200
# 2246/2246 [==============================] - 2s 792us/sample - loss: 0.0595 - val_loss: 0.5792
# Epoch 148/200
# 2246/2246 [==============================] - 2s 669us/sample - loss: 0.0591 - val_loss: 0.6733
# Epoch 149/200
# 2246/2246 [==============================] - 2s 759us/sample - loss: 0.0578 - val_loss: 0.5845
# Epoch 150/200
# 2246/2246 [==============================] - 2s 820us/sample - loss: 0.0654 - val_loss: 0.6354
# Epoch 151/200
# 2246/2246 [==============================] - 2s 712us/sample - loss: 0.0776 - val_loss: 0.5715
# Epoch 152/200
# 2246/2246 [==============================] - 2s 719us/sample - loss: 0.0622 - val_loss: 0.6505
# Epoch 153/200
# 2246/2246 [==============================] - 2s 755us/sample - loss: 0.0555 - val_loss: 0.8425
# Epoch 154/200
# 2246/2246 [==============================] - 2s 744us/sample - loss: 0.0571 - val_loss: 0.7956
# Epoch 155/200
# 2246/2246 [==============================] - 2s 733us/sample - loss: 0.0523 - val_loss: 0.6282
# Epoch 156/200
# 2246/2246 [==============================] - 2s 744us/sample - loss: 0.0703 - val_loss: 0.7142
# Epoch 157/200
# 2246/2246 [==============================] - 2s 998us/sample - loss: 0.0638 - val_loss: 0.6089
# Epoch 158/200
# 2246/2246 [==============================] - 2s 871us/sample - loss: 0.0535 - val_loss: 0.7297
# Epoch 159/200
# 2246/2246 [==============================] - 2s 756us/sample - loss: 0.0506 - val_loss: 0.9474
# Epoch 160/200
# 2246/2246 [==============================] - 2s 886us/sample - loss: 0.0561 - val_loss: 0.6660
# Epoch 161/200
# 2246/2246 [==============================] - 2s 687us/sample - loss: 0.0559 - val_loss: 0.7115
# Epoch 162/200
# 2246/2246 [==============================] - 2s 689us/sample - loss: 0.0558 - val_loss: 0.7042
# Epoch 163/200
# 2246/2246 [==============================] - 2s 699us/sample - loss: 0.0515 - val_loss: 0.5921
# Epoch 164/200
# 2246/2246 [==============================] - 2s 692us/sample - loss: 0.0485 - val_loss: 0.6421
# Epoch 165/200
# 2246/2246 [==============================] - 2s 712us/sample - loss: 0.0481 - val_loss: 0.6749
# Epoch 166/200
# 2246/2246 [==============================] - 2s 733us/sample - loss: 0.0470 - val_loss: 0.6456
# Epoch 167/200
# 2246/2246 [==============================] - 2s 710us/sample - loss: 0.0474 - val_loss: 0.8088
# Epoch 168/200
# 2246/2246 [==============================] - 2s 759us/sample - loss: 0.0497 - val_loss: 0.7062
# Epoch 169/200
# 2246/2246 [==============================] - 2s 693us/sample - loss: 0.0461 - val_loss: 0.7640
# Epoch 170/200
# 2246/2246 [==============================] - 2s 683us/sample - loss: 0.0533 - val_loss: 0.6107
# Epoch 171/200
# 2246/2246 [==============================] - 2s 695us/sample - loss: 0.0479 - val_loss: 0.7336
# Epoch 172/200
# 2246/2246 [==============================] - 2s 702us/sample - loss: 0.0471 - val_loss: 0.6431
# Epoch 173/200
# 2246/2246 [==============================] - 2s 708us/sample - loss: 0.0443 - val_loss: 0.7136
# Epoch 174/200
# 2246/2246 [==============================] - 2s 695us/sample - loss: 0.0464 - val_loss: 0.7095
# Epoch 175/200
# 2246/2246 [==============================] - 2s 758us/sample - loss: 0.0438 - val_loss: 0.6974
# Epoch 176/200
# 2246/2246 [==============================] - 2s 709us/sample - loss: 0.0451 - val_loss: 0.5194
# Epoch 177/200
# 2246/2246 [==============================] - 2s 736us/sample - loss: 0.0531 - val_loss: 0.6104
# Epoch 178/200
# 2246/2246 [==============================] - 2s 742us/sample - loss: 0.0470 - val_loss: 0.6821
# Epoch 179/200
# 2246/2246 [==============================] - 2s 748us/sample - loss: 0.0419 - val_loss: 0.6593
# Epoch 180/200
# 2246/2246 [==============================] - 2s 688us/sample - loss: 0.0451 - val_loss: 0.5747
# Epoch 181/200
# 2246/2246 [==============================] - 2s 687us/sample - loss: 0.0470 - val_loss: 0.6787
# Epoch 182/200
# 2246/2246 [==============================] - 2s 675us/sample - loss: 0.0414 - val_loss: 0.6894
# Epoch 183/200
# 2246/2246 [==============================] - 2s 697us/sample - loss: 0.0397 - val_loss: 0.6730
# Epoch 184/200
# 2246/2246 [==============================] - 2s 690us/sample - loss: 0.0363 - val_loss: 0.6972
# Epoch 185/200
# 2246/2246 [==============================] - 2s 668us/sample - loss: 0.0336 - val_loss: 0.5641
# Epoch 186/200
# 2246/2246 [==============================] - 1s 668us/sample - loss: 0.0337 - val_loss: 0.5790
# Epoch 187/200
# 2246/2246 [==============================] - 1s 668us/sample - loss: 0.0335 - val_loss: 0.7270
# Epoch 188/200
# 2246/2246 [==============================] - 2s 750us/sample - loss: 0.0357 - val_loss: 0.5956
# Epoch 189/200
# 2246/2246 [==============================] - 1s 661us/sample - loss: 0.0387 - val_loss: 0.6226
# Epoch 190/200
# 2246/2246 [==============================] - 1s 664us/sample - loss: 0.0378 - val_loss: 0.5369
# Epoch 191/200
# 2246/2246 [==============================] - 2s 680us/sample - loss: 0.0376 - val_loss: 0.7423
# Epoch 192/200
# 2246/2246 [==============================] - 2s 705us/sample - loss: 0.0458 - val_loss: 0.6175
# Epoch 193/200
# 2246/2246 [==============================] - 2s 728us/sample - loss: 0.0394 - val_loss: 0.5532
# Epoch 194/200
# 2246/2246 [==============================] - 2s 729us/sample - loss: 0.0390 - val_loss: 0.6056
# Epoch 195/200
# 2246/2246 [==============================] - 2s 768us/sample - loss: 0.0377 - val_loss: 0.6922
# Epoch 196/200
# 2246/2246 [==============================] - 1s 652us/sample - loss: 0.0371 - val_loss: 0.6192
# Epoch 197/200
# 2246/2246 [==============================] - 1s 658us/sample - loss: 0.0386 - val_loss: 0.6503
# Epoch 198/200
# 2246/2246 [==============================] - 2s 688us/sample - loss: 0.0369 - val_loss: 0.7578
# Epoch 199/200
# 2246/2246 [==============================] - 2s 733us/sample - loss: 0.0329 - val_loss: 0.7609
# Epoch 200/200
# 2246/2246 [==============================] - 2s 767us/sample - loss: 0.0313 - val_loss: 0.5522

# %%
plot_y1 = np.array(history.history['loss'])
plot_y2 = np.array(history.history['val_loss'])
plot_x = np.arange(plot_y1.shape[0])
plt.plot(plot_x, plot_y1)
plt.plot(plot_x, plot_y2)

# %%
xt = scaler.transform(x_test)

y_pred, weights = transformer_model.predict(xt)
y_pred = scaler.inverse_transform(y_pred)

print('RMSE', utils.rmse(y_test, y_pred)) 
print('MASE', utils.mase(y_test, y_pred, y_pred_baseline))
# Out:
# RMSE 23.307344804365027
# MASE 0.8349073366855815

# %%
fig, axes = plt.subplots(3, 2)
axes = [item for sublist in axes for item in sublist]

indexes = np.random.choice(np.arange(y_pred.shape[0]), len(axes))

for i, ax in zip(indexes, axes): 
    plot_x = np.squeeze(x_test[i])
    plot_y_pred = np.squeeze(y_pred[i])
    plot_y = np.squeeze(y_test[i])
    
    plot_x_numbers = np.arange(0, plot_x.shape[0])
    plot_y_numbers = np.arange(plot_x.shape[0], plot_x.shape[0] + plot_y.shape[0])

    ax.plot(plot_x_numbers, plot_x)
    ax.plot(plot_y_numbers, plot_y)
    ax.plot(plot_y_numbers, plot_y_pred)

# %%
def plot_weights(attention, x, y):     
    fig = plt.figure(figsize=(16, 8))
    
    for i in range(attention.shape[0]):
        ax = fig.add_subplot(2, 2, i+1)
        head_attn = attention[i]
        ax.matshow(head_attn, cmap='viridis')
        
#         ax.set_xticks(range(len(x)))
#         ax.set_yticks(range(len(y)))
        
random = np.random.randint(y_pred.shape[0])

plot_x = np.arange(x_test[random].shape[0] + y_pred[random].shape[0])
plt.plot(plot_x[0:x_test[random].shape[0]], x_test[random])
plt.plot(plot_x[-y_pred[random].shape[0]:], y_test[random])
plt.plot(plot_x[-y_pred[random].shape[0]:], y_pred[random])

plot_weights(weights['decoder_encoder_attention'][0][random], x_test[random], y_pred[random])
